# %%
from pbpstats.data_loader import StatsNbaEnhancedPbpLoader, StatsNbaPossessionLoader, StatsNbaShotsLoader, StatsNbaGameFinderLoader
from nba_api.stats.endpoints import playercareerstats, playerprofilev2, commonplayerinfo
import os
import psutil
import nba_api
import numpy as np
import json
import yaml
import os
import time
from glob import glob

# %%
def pprint(obj):
    print(yaml.dump(obj, default_flow_style=False))

# %%
game_files = glob(os.path.join(".","games","*"))
for game_file in game_files:
    with open(game_file,"r") as f:
        game = json.load(f)
    for play in game['plays']:
        pprint(play)
    break
# Out:
#    jahlil-okafor: {}
#     josh-hart:
#       2pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 3
#         description: Driving Layup Shot
#         made: false
#         value: 2
#         x: -1.9
#         y: 2.8
#     jrue-holiday: {}
#   TOR:
#     fred-vanvleet:
#       drb: 1
#     kyle-lowry: {}
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby:
#       blk: 1
#     pascal-siakam: {}
# possession_start_type: OffTimeout
# start_time: '4:09'
#
# end_time: '3:40'
# offense_team: TOR
# play_id: '4032'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     frank-jackson:
#       d_foul: 1
#     jahlil-okafor: {}
#     josh-hart: {}
#     jrue-holiday: {}
#   TOR:
#     fred-vanvleet:
#       fta: 2
#       ftm: 2
#       o_foul_drawn: 1
#       pts: 2
#     kyle-lowry: {}
#     marc-gasol: {}
#     og-anunoby: {}
#     pascal-siakam: {}
# possession_start_type: OffAtRimBlock
# start_time: '3:46'
#
# end_time: '3:24'
# offense_team: NOP
# play_id: '4033'
# player_stats:
#   NOP:
#     brandon-ingram:
#       2pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 7
#         description: Floating Jump shot
#         made: false
#         value: 2
#         x: -2.4
#         y: 6.7
#     frank-jackson: {}
#     jahlil-okafor: {}
#     josh-hart: {}
#     jrue-holiday: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     og-anunoby: {}
#     pascal-siakam:
#       drb: 1
# possession_start_type: OffFTMake
# start_time: '3:40'
#
# end_time: '3:18'
# offense_team: TOR
# play_id: '4034'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     frank-jackson: {}
#     jahlil-okafor:
#       d_foul: 1
#     josh-hart: {}
#     jrue-holiday: {}
#   TOR:
#     fred-vanvleet:
#       ast: 1
#     kyle-lowry: {}
#     marc-gasol: {}
#     og-anunoby: {}
#     pascal-siakam:
#       2pa: 1
#       2pm: 1
#       fga: 1
#       fgm: 1
#       fta: 1
#       ftm: 1
#       o_foul_drawn: 1
#       pts: 3
#       shots:
#       - 2nd_chance: false
#         assisted: true
#         d: 2
#         description: Driving Layup Shot
#         made: true
#         value: 2
#         x: 2.0
#         y: 2.2
# possession_start_type: OffShortMidRangeMiss
# start_time: '3:24'
#
# end_time: '2:59'
# offense_team: NOP
# play_id: '4035'
# player_stats:
#   NOP:
#     brandon-ingram:
#       3pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 23
#         description: Jump Shot
#         made: false
#         value: 3
#         x: 23.1
#         y: -0.6
#     frank-jackson: {}
#     jahlil-okafor: {}
#     josh-hart: {}
#     jrue-holiday: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     og-anunoby: {}
#     pascal-siakam:
#       drb: 1
# possession_start_type: OffFTMake
# start_time: '3:18'
#
# end_time: '2:51'
# offense_team: TOR
# play_id: '4036'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     frank-jackson: {}
#     jahlil-okafor: {}
#     josh-hart: {}
#     jrue-holiday: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry:
#       ast: 1
#     marc-gasol: {}
#     og-anunoby: {}
#     pascal-siakam:
#       2pa: 1
#       2pm: 1
#       fga: 1
#       fgm: 1
#       pts: 2
#       shots:
#       - 2nd_chance: false
#         assisted: true
#         d: 7
#         description: Floating Jump shot
#         made: true
#         value: 2
#         x: 3.4
#         y: 6.2
# possession_start_type: OffCorner3Miss
# start_time: '2:59'
#
# end_time: '2:37'
# offense_team: NOP
# play_id: '4037'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     frank-jackson: {}
#     jahlil-okafor:
#       fta: 2
#       ftm: 1
#       o_foul_drawn: 1
#       pts: 1
#     josh-hart: {}
#     jrue-holiday: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     og-anunoby: {}
#     pascal-siakam:
#       d_foul: 1
# possession_start_type: OffShortMidRangeMake
# start_time: '2:51'
#
# end_time: '2:14'
# offense_team: TOR
# play_id: '4038'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     frank-jackson: {}
#     jahlil-okafor:
#       d_foul: 1
#     jj-redick: {}
#     josh-hart: {}
#     jrue-holiday: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry:
#       fta: 3
#       ftm: 2
#       o_foul_drawn: 1
#       pts: 2
#     marc-gasol: {}
#     og-anunoby: {}
#     pascal-siakam: {}
#     serge-ibaka: {}
# possession_start_type: OffFTMake
# start_time: '2:37'
#
# end_time: '2:03'
# offense_team: NOP
# play_id: '4039'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     josh-hart: {}
#     jrue-holiday:
#       2pa: 1
#       2pm: 1
#       fga: 1
#       fgm: 1
#       pts: 2
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 1
#         description: Driving Finger Roll Layup Shot
#         made: true
#         value: 2
#         x: 1.4
#         y: 0.4
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     og-anunoby: {}
#     pascal-siakam: {}
#     serge-ibaka: {}
# possession_start_type: OffFTMake
# start_time: '2:14'
#
# end_time: '1:36'
# offense_team: TOR
# play_id: '4040'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     josh-hart: {}
#     jrue-holiday: {}
#     nicolo-melli:
#       drb: 1
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry:
#       3pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 27
#         description: Pullup Jump shot
#         made: false
#         value: 3
#         x: -0.2
#         y: 27.2
#     og-anunoby: {}
#     pascal-siakam: {}
#     serge-ibaka: {}
# possession_start_type: OffAtRimMake
# start_time: '2:03'
#
# end_time: '1:28'
# offense_team: NOP
# play_id: '4041'
# player_stats:
#   NOP:
#     brandon-ingram:
#       ast: 1
#     jj-redick: {}
#     josh-hart:
#       3pa: 1
#       3pm: 1
#       fga: 1
#       fgm: 1
#       pts: 3
#       shots:
#       - 2nd_chance: false
#         assisted: true
#         d: 24
#         description: Jump Shot
#         made: true
#         value: 3
#         x: -23.1
#         y: 9.0
#     jrue-holiday: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     og-anunoby: {}
#     pascal-siakam: {}
#     serge-ibaka: {}
# possession_start_type: OffArc3Miss
# start_time: '1:36'
#
# end_time: '1:19'
# offense_team: TOR
# play_id: '4042'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     josh-hart: {}
#     jrue-holiday: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet:
#       3pa: 1
#       3pm: 1
#       fga: 1
#       fgm: 1
#       pts: 3
#       shots:
#       - 2nd_chance: false
#         assisted: true
#         d: 22
#         description: Jump Shot
#         made: true
#         value: 3
#         x: -22.3
#         y: -1.8
#     kyle-lowry:
#       ast: 1
#     marc-gasol: {}
#     og-anunoby: {}
#     pascal-siakam: {}
#     serge-ibaka: {}
# possession_start_type: OffTimeout
# start_time: '1:28'
#
# end_time: 0:59
# offense_team: NOP
# play_id: '4043'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick:
#       2pa: 1
#       2pm: 1
#       fga: 1
#       fgm: 1
#       pts: 2
#       shots:
#       - 2nd_chance: false
#         assisted: true
#         d: 19
#         description: Pullup Jump shot
#         made: true
#         value: 2
#         x: 15.0
#         y: 12.1
#     josh-hart: {}
#     jrue-holiday: {}
#     nicolo-melli:
#       ast: 1
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     og-anunoby: {}
#     pascal-siakam: {}
# possession_start_type: OffCorner3Make
# start_time: '1:19'
#
# end_time: 0:50
# offense_team: TOR
# play_id: '4044'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick:
#       d_foul_drawn: 1
#     josh-hart: {}
#     jrue-holiday: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     og-anunoby: {}
#     pascal-siakam:
#       o_foul: 1
#       tov: 1
# possession_start_type: OffLongMidRangeMake
# start_time: 0:59
#
# end_time: 0:32
# offense_team: NOP
# play_id: '4045'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     josh-hart:
#       tov: 1
#     jrue-holiday: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet:
#       stl: 1
#     kyle-lowry: {}
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffDeadball
# start_time: 0:50
#
# end_time: 0:29
# offense_team: TOR
# play_id: '4046'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     josh-hart:
#       d_foul: 1
#     jrue-holiday: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry:
#       fta: 2
#       ftm: 2
#       o_foul_drawn: 1
#       pts: 2
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffLiveBallTurnover
# start_time: 0:32
#
# end_time: 0:08
# offense_team: NOP
# play_id: '4047'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     josh-hart: {}
#     jrue-holiday:
#       3pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 24
#         description: Pullup Jump shot
#         made: false
#         value: 3
#         x: 21.8
#         y: 11.3
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     norman-powell:
#       drb: 1
#     og-anunoby: {}
# possession_start_type: OffTimeout
# start_time: 0:29
#
# end_time: 0:00
# offense_team: TOR
# play_id: '4048'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     frank-jackson: {}
#     jj-redick: {}
#     josh-hart: {}
#     jrue-holiday: {}
#     kenrich-williams: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     norman-powell:
#       3pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 27
#         description: Pullup Jump shot
#         made: false
#         value: 3
#         x: 4.6
#         y: 27.4
#     og-anunoby: {}
# possession_start_type: OffTimeout
# start_time: 0:08
#
# end_time: '4:45'
# offense_team: TOR
# play_id: '5001'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     jrue-holiday: {}
#     lonzo-ball: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry:
#       ast: 1
#     marc-gasol: {}
#     norman-powell:
#       2pa: 1
#       2pm: 1
#       fga: 1
#       fgm: 1
#       pts: 2
#       shots:
#       - 2nd_chance: false
#         assisted: true
#         d: 2
#         description: Cutting Layup Shot
#         made: true
#         value: 2
#         x: 1.9
#         y: 1.7
#     og-anunoby: {}
# possession_start_type: OffDeadball
# start_time: '5:00'
#
# end_time: '4:31'
# offense_team: NOP
# play_id: '5002'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick:
#       3pa: 1
#       3pm: 1
#       fga: 1
#       fgm: 1
#       pts: 3
#       shots:
#       - 2nd_chance: false
#         assisted: true
#         d: 24
#         description: Pullup Jump shot
#         made: true
#         value: 3
#         x: 14.9
#         y: 19.9
#     jrue-holiday: {}
#     lonzo-ball: {}
#     nicolo-melli:
#       ast: 1
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffAtRimMake
# start_time: '4:45'
#
# end_time: '4:17'
# offense_team: TOR
# play_id: '5003'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     jrue-holiday: {}
#     lonzo-ball: {}
#     nicolo-melli:
#       drb: 1
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry:
#       3pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 24
#         description: Jump Shot
#         made: false
#         value: 3
#         x: -21.8
#         y: 10.8
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffArc3Make
# start_time: '4:31'
#
# end_time: '4:05'
# offense_team: NOP
# play_id: '5004'
# player_stats:
#   NOP:
#     brandon-ingram:
#       2pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 15
#         description: Pullup Jump shot
#         made: false
#         value: 2
#         x: -5.7
#         y: 13.9
#     jj-redick: {}
#     jrue-holiday: {}
#     lonzo-ball: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol:
#       drb: 1
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffArc3Miss
# start_time: '4:17'
#
# end_time: '3:50'
# offense_team: TOR
# play_id: '5005'
# player_stats:
#   NOP:
#     brandon-ingram:
#       blk: 1
#     jj-redick:
#       drb: 1
#     jrue-holiday: {}
#     lonzo-ball: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby:
#       3pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 22
#         description: Jump Shot
#         made: false
#         value: 3
#         x: -22.5
#         y: -1.3
# possession_start_type: OffLongMidRangeMiss
# start_time: '4:05'
#
# end_time: '3:38'
# offense_team: NOP
# play_id: '5006'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     jrue-holiday: {}
#     lonzo-ball:
#       2pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 21
#         description: Jump Shot
#         made: false
#         value: 2
#         x: -20.9
#         y: 2.6
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     norman-powell:
#       drb: 1
#     og-anunoby: {}
# possession_start_type: OffCorner3Block
# start_time: '3:50'
#
# end_time: '3:21'
# offense_team: TOR
# play_id: '5007'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     jrue-holiday: {}
#     lonzo-ball:
#       drb: 1
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol:
#       3pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 24
#         description: Jump Shot
#         made: false
#         value: 3
#         x: -14.5
#         y: 19.9
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffLongMidRangeMiss
# start_time: '3:38'
#
# end_time: '2:55'
# offense_team: NOP
# play_id: '5008'
# player_stats:
#   NOP:
#     brandon-ingram:
#       tov: 1
#     derrick-favors: {}
#     jj-redick:
#       o_foul_drawn: 1
#     jrue-holiday: {}
#     lonzo-ball: {}
#     nicolo-melli:
#       o_foul_drawn: 1
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry:
#       d_foul: 1
#     marc-gasol:
#       d_foul: 1
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffArc3Miss
# start_time: '3:21'
#
# end_time: '2:37'
# offense_team: TOR
# play_id: '5009'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     derrick-favors:
#       d_foul: 1
#     jj-redick: {}
#     jrue-holiday: {}
#     lonzo-ball: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol:
#       2pa: 1
#       2pm: 1
#       fga: 1
#       fgm: 1
#       fta: 1
#       ftm: 1
#       o_foul_drawn: 1
#       pts: 3
#       shots:
#       - 2nd_chance: false
#         assisted: true
#         d: 3
#         description: Driving Layup Shot
#         made: true
#         value: 2
#         x: 2.7
#         y: 2.0
#     norman-powell:
#       ast: 1
#     og-anunoby: {}
# possession_start_type: OffDeadball
# start_time: '2:55'
#
# end_time: '2:23'
# offense_team: NOP
# play_id: '5010'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     derrick-favors: {}
#     jj-redick: {}
#     jrue-holiday:
#       2pa: 1
#       2pm: 1
#       fga: 1
#       fgm: 1
#       pts: 2
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 1
#         description: Driving Finger Roll Layup Shot
#         made: true
#         value: 2
#         x: -1.8
#         y: 0.1
#     lonzo-ball: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffFTMake
# start_time: '2:37'
#
# end_time: '2:06'
# offense_team: TOR
# play_id: '5011'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     derrick-favors: {}
#     jj-redick: {}
#     jrue-holiday: {}
#     lonzo-ball:
#       d_foul: 1
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry:
#       fta: 2
#       ftm: 2
#       o_foul_drawn: 1
#       pts: 2
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffAtRimMake
# start_time: '2:23'
#
# end_time: '1:44'
# offense_team: NOP
# play_id: '5012'
# player_stats:
#   NOP:
#     brandon-ingram:
#       2pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 10
#         description: Turnaround Fadeaway shot
#         made: false
#         value: 2
#         x: -2.4
#         y: 10.7
#     derrick-favors: {}
#     jj-redick: {}
#     jrue-holiday: {}
#     lonzo-ball: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     norman-powell:
#       drb: 1
#     og-anunoby: {}
# possession_start_type: OffFTMake
# start_time: '2:06'
#
# end_time: '1:27'
# offense_team: TOR
# play_id: '5013'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     derrick-favors: {}
#     jj-redick: {}
#     jrue-holiday: {}
#     lonzo-ball: {}
#   TOR:
#     fred-vanvleet:
#       3pa: 1
#       3pm: 1
#       fga: 1
#       fgm: 1
#       pts: 3
#       shots:
#       - 2nd_chance: false
#         assisted: true
#         d: 22
#         description: Jump Shot
#         made: true
#         value: 3
#         x: -22.3
#         y: -1.8
#     kyle-lowry: {}
#     marc-gasol:
#       ast: 1
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffShortMidRangeMiss
# start_time: '1:44'
#
# end_time: '1:14'
# offense_team: NOP
# play_id: '5014'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     derrick-favors: {}
#     jj-redick: {}
#     josh-hart:
#       3pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 23
#         description: Jump Shot
#         made: false
#         value: 3
#         x: 23.0
#         y: -0.6
#     jrue-holiday: {}
#     lonzo-ball: {}
#     nicolo-melli:
#       2pa: 1
#       fga: 1
#       orb: 1
#       shots:
#       - 2nd_chance: true
#         assisted: false
#         d: 0
#         description: Tip Layup Shot
#         made: false
#         value: 2
#         x: 0.0
#         y: -0.6
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby:
#       drb: 1
# possession_start_type: OffTimeout
# start_time: '1:27'
#
# end_time: 0:56
# offense_team: TOR
# play_id: '5015'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     josh-hart: {}
#     jrue-holiday: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry:
#       3pa: 1
#       3pm: 1
#       fga: 1
#       fgm: 1
#       pts: 3
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 25
#         description: Pullup Jump shot
#         made: true
#         value: 3
#         x: 14.7
#         y: 20.6
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffAtRimMiss
# start_time: '1:14'
#
# end_time: 0:40
# offense_team: NOP
# play_id: '5016'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     josh-hart: {}
#     jrue-holiday: {}
#     nicolo-melli:
#       3pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 23
#         description: Jump Shot
#         made: false
#         value: 3
#         x: 23.0
#         y: -0.5
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol:
#       drb: 1
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffArc3Make
# start_time: 0:56
#
# end_time: 0:16
# offense_team: TOR
# play_id: '5017'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     josh-hart: {}
#     jrue-holiday:
#       d_foul: 1
#     nicolo-melli:
#       drb: 1
#   TOR:
#     fred-vanvleet:
#       2pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 1
#         description: Driving Finger Roll Layup Shot
#         made: false
#         value: 2
#         x: -1.0
#         y: 1.1
#     kyle-lowry:
#       o_foul_drawn: 1
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffCorner3Miss
# start_time: 0:40
#
# end_time: 0:06
# offense_team: NOP
# play_id: '5018'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick:
#       tov: 1
#     josh-hart:
#       o_foul_drawn: 1
#     jrue-holiday:
#       3pa: 1
#       fga: 1
#       shots:
#       - 2nd_chance: false
#         assisted: false
#         d: 27
#         description: Step Back Jump shot
#         made: false
#         value: 3
#         x: -13.0
#         y: 23.9
#     nicolo-melli:
#       orb: 1
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol:
#       d_foul: 1
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffAtRimMiss
# start_time: 0:16
#
# end_time: 0:00
# offense_team: TOR
# play_id: '5019'
# player_stats:
#   NOP:
#     brandon-ingram: {}
#     jj-redick: {}
#     josh-hart: {}
#     jrue-holiday: {}
#     nicolo-melli: {}
#   TOR:
#     fred-vanvleet: {}
#     kyle-lowry: {}
#     marc-gasol: {}
#     norman-powell: {}
#     og-anunoby: {}
# possession_start_type: OffDeadball
# start_time: 0:06
